# %% [markdown]
# # DATASET RANDOM SPLITTER

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# AFAD --> 15-40 ages
afad_TRAIN_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/afad_test.csv'
afad_TEST_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/afad_train.csv'
afad_VALID_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/afad_valid.csv'

# CACD --> 14-62 ages
cacd_TRAIN_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/cacd_train.csv'
cacd_TEST_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/cacd_test.csv'
cacd_VALID_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/cacd_valid.csv'

# MORPH --> 16-70 ages
morph_TRAIN_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/morph2_train.csv'
morph_TEST_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/morph2_test.csv'
morph_VALID_CSV_PATH = 'C:/Users/mirvi/Desktop/mii/UAB/3.2/Xneuronals/projecte/XNAPproject-grup_15/datasets/morph2_valid.csv'


afad_path = [afad_TRAIN_CSV_PATH, afad_TEST_CSV_PATH, afad_VALID_CSV_PATH]
cacd_path = [cacd_TRAIN_CSV_PATH, cacd_TEST_CSV_PATH, cacd_VALID_CSV_PATH]
morph_path = [morph_TRAIN_CSV_PATH, morph_TEST_CSV_PATH, morph_VALID_CSV_PATH]

# %% [markdown]
# ## VALOREM DISTRIBUCIÓ INICIAL

# %%
# SHOW DATA DISTRIBUTION

def plot_class_distribution(df, title):
    class_counts = df['age'].value_counts()
    classes = class_counts.index
    counts = class_counts.values

    plt.figure(figsize=(8, 6))
    plt.bar(classes, counts)
    plt.xlabel('Clase')
    plt.ylabel('Número de muestras')
    plt.title(title)
    plt.xticks(classes)
    plt.show()

type = ['train', 'test', 'valid']

# %% [markdown]
# ## SPLIT DATASET

# %%
# create directory to save the splitted datasets
if not os.path.exists('./RANDOM_splitted_datasets'):
    os.makedirs('./RANDOM_splitted_datasets')

# %%
reduct_value = 0.3
reduced_datasets = []  # Lista para almacenar los conjuntos de datos reducidos

for i, path in enumerate(afad_path):
    print('\nAFAD', type[i])
    df = pd.read_csv(path)
    n_samples = int(reduct_value * len(df))
    reduced_df = df.sample(n=n_samples, random_state=42)
    plot_class_distribution(df, f'original {type[i]}')
    plot_class_distribution(reduced_df, f'reduced {type[i]}')
    print('original len:',len(df))
    print('reduced len:',len(reduced_df))

    # save reduced dataset
    df.to_csv(f'./RANDOM_splitted_datasets/afad_splitRANDOM_{type[i]}.csv', index=False)
# Out:
# AFAD train
# original len: 32762
# reduced len: 9828
#
# AFAD test
# original len: 118491
# reduced len: 35547
#
# AFAD valid
# original len: 13165
# reduced len: 3949

# %%
for i, path in enumerate(cacd_path):
    print('\nCACD', type[i])
    df = pd.read_csv(path)
    n_samples = int(reduct_value * len(df))
    reduced_df = df.sample(n=n_samples, random_state=42)
    plot_class_distribution(df, f'original {type[i]}')
    plot_class_distribution(reduced_df, f'reduced {type[i]}')
    print('original len:',len(df))
    print('reduced len:',len(reduced_df))

    # save reduced dataset
    df.to_csv(f'./RANDOM_splitted_datasets/cacd_splitRANDOM_{type[i]}.csv', index=False)
# Out:
# CACD train
# original len: 114804
# reduced len: 34441
#
# CACD test
# original len: 31890
# reduced len: 9567
#
# CACD valid
# original len: 12755
# reduced len: 3826

# %%
for i, path in enumerate(morph_path):
    print('\nMORPH', type[i])
    df = pd.read_csv(path)
    n_samples = int(reduct_value * len(df))
    reduced_df = df.sample(n=n_samples, random_state=42)
    plot_class_distribution(df, f'original {type[i]}')
    plot_class_distribution(reduced_df, f'reduced {type[i]}')
    print('original len:',len(df))
    print('reduced len:',len(reduced_df))

    # save reduced dataset
    df.to_csv(f'./RANDOM_splitted_datasets/morph_splitRANDOM_{type[i]}.csv', index=False)
# Out:
# MORPH train
# original len: 39764
# reduced len: 11929
#
# MORPH test
# original len: 11044
# reduced len: 3313
#
# MORPH valid
# original len: 4416
# reduced len: 1324
